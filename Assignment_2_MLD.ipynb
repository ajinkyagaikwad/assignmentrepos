# %%
###Star pattern

# %%
for i in range(1,5):
	for j in range(i):
		print('*',end='')
	print()
for i in range(5,0,-1):
	for j in range(i):
		print('*',end='')
	print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
###Reverse a string

# %%
name = input('Enter a string ')
print('Reversed string is ', name[::-1])
# Out:
# Enter a string lockdown
# Reversed string is  nwodkcol
