# %%
#Custom-built reduce function that works for basic operations: add,subtract,multiply,divide. Similar logic can be used to build solution for other operations too
x = [3,4,5,12,16]
def myreduce(choice,lst):
	add=0
	sub=0
	mult=1
	div=1
	if choice=='+':
		for i in range(len(lst)):
			add += lst[i]
		return add
	if choice=='-':
		for i in range(len(lst)):
			sub -= lst[i]
		return sub
	if choice=='*':
		for i in range(len(lst)):
			mult *= lst[i]
		return mult
	if choice=='/':
		for i in range(len(lst)):
			div /= lst[i]
		return div

a = myreduce('+',x)   #returns reduced sum
b = myreduce('-',x)   #returns reduce subtraction
c = myreduce('*',x)   #returns reduce product
d = myreduce('/',x)   #returns division
print(a,b,c)
print("{:.4f}".format(d))   #formatting the division upto 4 decimal places.
# Out:
# 40 -40 11520
# 0.0001

# %%
#Custom-built filter function. It demonstrates operations like filtering out numbers less than 'n'.
l = [3,4,5,6,7,8]
final =[]
def filter_greater(lst):
	n=int(input("Enter minimum threshold "))
	for i in range(len(lst)):
		if lst[i]>n:
			final.append(lst[i])
	return final
def my_filter(choice,lst):
	if choice == '>':
		result=filter_greater(lst)
	return result

out = my_filter('>',l)
print("Filtered list is :",out)
# Out:
# Enter minimum threshold 5
# Filtered list is : [6, 7, 8]

# %%
###List comprehensions

# %%
###First
input_str = ['x','y','z']
output=[]
for i in range(len(input_str)):
	for j in range(1,len(input_str)+2):
		output.append(input_str[i]*j)

print(output)
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
###Second
input_str = ['x','y','z']
for i in range(len(input_str)-1):
	for j in range(len(input_str)):
		input_str.append(input_str[j]+input_str[j])

print(input_str)
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xx', 'yy', 'zz', 'xxxx', 'yyyy', 'zzzz']

# %%
#Third
l = [2,3,4]
m=[[l[j]+i] for i in range(len(l)) for j in range(len(l))]
print(m)
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
#Fourth
l = [2,3,4,5]
m = [[l[j]+i for j in range(len(l))] for i in range(len(l))]
print(m)
# Out:
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
