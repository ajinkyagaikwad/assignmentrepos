# %%
###Area of a triangle

# %%
import math
class Triangle:
	def __init__(self,side1,side2,side3):
		self.side1=side1
		self.side2=side2
		self.side3=side3
	def area(self):
		s=(self.side1+self.side2+self.side3)/2
		s1=(s-self.side1)*(s-self.side1)*(s-self.side1)
		s1 = s*s1
		return math.pow(s1,0.5)
	
print("Enter 3 sides of a triangle: ")
a = int(input("1->"))
b = int(input("2->"))
c = int(input("3->"))	
A = Triangle(a,b,c)
final = A.area()
print("Area of triangle is {:.4f}".format(final))
# Out:
# Enter 3 sides of a triangle:
# 1->3
# 2->4
# 3->6
# Area of triangle is 16.6939

# %%
###Filter long words

# %%
def filter_long_words(lst,num):
	result = list(filter(lambda x: len(x)>n, l))
	return result

l = []
while(True):
	char = input("Enter a word. Press 'q' to quit. ")
	if char=='q':
		break
	l.append(char)
n = int(input("Enter a minimum threshold: "))

final = filter_long_words(l,n)
print("Filtered output", final)
# Out:
# Enter a word. Press 'q' to quit. today
# Enter a word. Press 'q' to quit. is
# Enter a word. Press 'q' to quit. friday
# Enter a word. Press 'q' to quit. q
# Enter a minimum threshold: 4
# Filtered output ['today', 'friday']

# %%
###Mapping string with number of words in it
input_str = "My name is Ajinkya"
l = input_str.split()
def find_length(s):
	return len(s)
x = list(map(find_length, l))
print("List of words is: ",l)
print("Desired output is: ",x)
# Out:
# List of words is:  ['My', 'name', 'is', 'Ajinkya']
# Desired output is:  [2, 4, 2, 7]

# %%
###Vowel detection

def detect_vowel(char):
	if char in ('a','e','i','o','u','A','E','I','O','U'):
		return True
	else:
		return False

input_char = input('Enter a character: ')
result=detect_vowel(input_char)
if result==True:
  print('A vowel')
else:
  print('Not a vowel')
# Out:
# Enter a character: I
# A vowel
